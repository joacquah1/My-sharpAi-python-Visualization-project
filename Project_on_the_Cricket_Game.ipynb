# %% [markdown]
# <a href="https://colab.research.google.com/github/joacquah1/My-sharpAi-python-Visualization-project/blob/main/Project_on_the_Cricket_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def user_Bat():
    print("Ran")
    user_score =0
    computer_score=0
    
    while True:
        user_ran=int(input("Choose a number between 1-6 !!!"))
        computer_ran = random.choice([1,2,3,4,5,6])
        if user_ran != computer_ran:
            print("-----------------------------------------------------------------------------------------------")
            print(f"You have choosen {user_ran} and computer has choosen {computer_ran}")
            user_score +=user_ran
            print("-----------------------------------------------------------------------------------------------")
            print(f"Users current score is {user_score}")
            print("-----------------------------------------------------------------------------------------------")
        else:
            print(f"You have choosen {user_ran} and computer has choosen {computer_ran}")
            print("-----------------------------------------------------------------------------------------------")
            print("------------------------------------------------------")
            print(f"User is OUT.\nThe total run needed for computer to win is {user_score+1}...Computer's turn! ")
            print("------------------------------------------------------")
            print("-----------------------------------------------------------------------------------------------")
            while True:
                user_ran=int(input("Choose a number between 1-6 !!!"))
                computer_ran = random.choice([1,2,3,4,5,6])
                if user_ran != computer_ran:
                    print(f"Computer has choosen {computer_ran} and user choose {user_ran}")
                    print("-----------------------------------------------------------------------------------------------")
                    computer_score +=computer_ran
                    print(f"Computer current score is {computer_score}")
                    print("-----------------------------------------------------------------------------------------------")
                    if computer_score>user_score:
                        print("Hahaha...Computer just won!")
                        print("-----------------------------------------------------------------------------------------------")
                        break
                    else:
                        pass
                else:
                    print(f"Computer choose {computer_ran} and User has choosen {user_ran}")
                    print("-----------------------------------------------------------------------------------------------")
                    print(f"You kicked computer also OUT.\n User total score was {user_ran} and computer score was {computer_score}")
                    print("-----------------------------------------------------------------------------------------------")
                    print("-----------------------------------------------------------------------------------------------")
                    print("CONGRATULATIONS User....YOU WON!")
                    print("-----------------------------------------------------------------------------------------------")
                    print("-----------------------------------------------------------------------------------------------")
                    
                    break
                    
            break
            
            
            
def computer_Bat():
    user_score =0
    computer_score=0
    
    while True:
        user_ran=int(input("Choose a number between 1-6 !!!"))
        computer_ran = random.choice([1,2,3,4,5,6])
        if user_ran != computer_ran:
            print(f"You have choosen {user_ran} and computer has choosen {computer_ran}")
            computer_score +=computer_ran
            print("-----------------------------------------------------------------------------------------------")
            print(f"Computer's current score is {computer_score}")
            print("-----------------------------------------------------------------------------------------------")
        else:
            print(f"You have choosen {user_ran} and computer has choosen {computer_ran}")
            print("-----------------------------------------------------------------------------------------------")
            print("------------------------------------------------------")
            print(f"Computer is OUT.\nThe total run needed for User to win is {computer_score+1}...User's turn! ")
            print("------------------------------------------------------")
            print("-----------------------------------------------------------------------------------------------")
            while True:    
                user_ran=int(input("Choose a number between 1-6 !!!"))
                computer_ran = random.choice([1,2,3,4,5,6])
                if user_ran != computer_ran:
                    print(f"Computer has choosen {computer_ran} and user choose {user_ran}")
                    print("-----------------------------------------------------------------------------------------------")
                    user_score +=user_ran
                    print(f"User's current score is {user_score}")
                    print("-----------------------------------------------------------------------------------------------")
                    if computer_score<user_score:
                        print("-----------------------------------------------------------------------------------------------")
                        print("-----------------------------------------------------------------------------------------------")
                        print("Hahaha...User just won.\nCONGRATULATIONS !")
                        print("-----------------------------------------------------------------------------------------------")
                        print("-----------------------------------------------------------------------------------------------")
                        break
                    else:
                        pass
                else:
                    print(f"Computer choose {computer_ran} and User has choosen {user_ran}")
                    print("-----------------------------------------------------------------------------------------------")
                    print(f"Computer kicked User also OUT.\n User total score was {user_ran} and computer score was {computer_score}")
                    print("-----------------------------------------------------------------------------------------------")
                    print("-----------------------------------------------------------------------------------------------")
                    print("Computer just defeated User....\nComputer WON!")
                    print("-----------------------------------------------------------------------------------------------")
                    print("-----------------------------------------------------------------------------------------------")
                    break
                    
            break
            







                
import random            
def game():
    import random 
    print("Let the toss begin")
    print("ODD or EVEN?")
    print("-----------------------------------------------------------------------------------------------")
    user_toss_choice= input("Select your choice: ODD or EVEN?:").lower()
    user_number_choice= int(input("Choose a number between 1-6 !!!:"))
    computer_number_choice= random.choice([1,2,3,4,5,6]) 
    Toss_Decision=user_number_choice+computer_number_choice
    print(f"Computer also tossed {computer_number_choice}.\nThe total outcome is {Toss_Decision}")
    print("-----------------------------------------------------------------------------------------------")
    if (user_toss_choice =="even" and (Toss_Decision)%2==0) or (user_toss_choice =="odd" and (Toss_Decision)%2!=0) :
        user_option =input("You have won the toss, do you like to do BAT or BALL?:").lower()
        print("-----------------------------------------------------------------------------------------------")
        if user_option=="bat":
            print("User Bats First")
            print("-----------------------------------------------------------------------------------------------")
            return user_Bat()
        
        else:
            print("Computer is Batting First")
            print("-----------------------------------------------------------------------------------------------")
            return computer_Bat()


    else:
        computer_selection=random.choice(["batt","ball"])
        if computer_selection=="batt":
            print(f"You have lost the toss and computer has choose {computer_selection}ing so you will do balling")
            print("-----------------------------------------------------------------------------------------------")
            return computer_Bat()
        else:
            print(f"You have lost the toss and computer has choose {computer_selection}ing so you will do batting")
            print("-----------------------------------------------------------------------------------------------")
            return user_Bat()

    
      
game()
# Out:
# Let the toss begin
# ODD or EVEN?
# -----------------------------------------------------------------------------------------------
# Select your choice: ODD or EVEN?:even
# Choose a number between 1-6 !!!:3
# Computer also tossed 1.
# The total outcome is 4
# -----------------------------------------------------------------------------------------------
# You have won the toss, do you like to do BAT or BALL?:bat
# -----------------------------------------------------------------------------------------------
# User Bats First
# -----------------------------------------------------------------------------------------------
# Ran
# Choose a number between 1-6 !!!5
# -----------------------------------------------------------------------------------------------
# You have choosen 5 and computer has choosen 6
# -----------------------------------------------------------------------------------------------
# Users current score is 5
# ...
